# %% [markdown]
# First, install [mpld3][1]
#
# ```
# pip install mpld3
# ```
#
# [1]: http://mpld3.github.io/

# %%
# !pip install mpld3
# Out:
# Collecting mpld3
#   Downloading mpld3-0.3.tar.gz (788kB)
#     100% |████████████████████████████████| 798kB 194kB/s ta 0:00:01
# Building wheels for collected packages: mpld3
# done
#   Stored in directory: /Users/bater.makhabel/Library/Caches/pip/wheels/69/bc/68/7ca3b696749d183e998968fc24b0ff3c5e119d9e68bf495b07
# Successfully built mpld3
# Installing collected packages: mpld3
# Successfully installed mpld3-0.3
# You are using pip version 9.0.1, however version 9.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import mpld3

mpld3.enable_notebook()

# Turn off matplotlib interactive mode
# plt.ioff()

# %%
plt.plot(np.array([3,1,4,1,5]), 'ks-', mec='w', mew=5, ms=20)

# %%
n = 50
x, y, z, s, ew = np.random.rand(5, n)
c, ec = np.random.rand(2, n, 4)
area_scale, width_scale = 500, 5

fig, ax = plt.subplots()
sc = ax.scatter(x, y, 
                c=c,
                s=np.square(s)*area_scale,
                edgecolor=ec,
                # The linewidth parameter must be a list, i.e., it cannot be
                # a NumPy array. Without the conversion to a list, the call
                # to scatter will throw an exception since a NumPy array
                # cannot be serialized to JSON.
                linewidth=list(ew*width_scale))
ax.grid()
