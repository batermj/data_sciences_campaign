# %%
# encoding=utf8

# %%
#文本分类的数据预处理

# %%
import nltk
#from nltk.corpus import state_union
#from nltk.tokenize import PunktSentenceTokenizer

# %%
#https://www.crummy.com/software/BeautifulSoup/
#http://blog.csdn.net/sftec/article/details/52884915
from bs4 import BeautifulSoup

# %%
import re
#Python Re模块
#http://python.jobbole.com/88729/

# %%
import pprint
#https://docs.python.org/2/library/pprint.html

# %%
import chardet
#https://www.cnblogs.com/weidiao/p/7271978.html
#Python使用chardet包自动检测编码

# %%
import urllib 
#https://www.cnblogs.com/sysu-blackbear/p/3629420.html

# %%
#1,去除html tag（对于爬虫抓下来的web page）

# %%
url="http://www.36kr.com"
content=urllib.request.urlopen(url).read() 
print(content)
# Out:
# b'<!DOCTYPE html>\n<html lang="zh-CN" class="pc-loading">\n<head>\n    <title>36\xe6\xb0\xaa_\xe8\xae\xa9\xe4\xb8\x80\xe9\x83\xa8\xe5\x88\x86\xe4\xba\xba\xe5\x85\x88\xe7\x9c\x8b\xe5\x88\xb0\xe6\x9c\xaa\xe6\x9d\xa5</title>\r\n<meta name="keywords" content="\xe5\x88\x9b\xe4\xb8\x9a,\xe4\xba\x92\xe8\x81\x94\xe7\xbd\x91\xe5\x88\x9b\xe4\xb8\x9a,\xe4\xba\x92\xe8\x81\x94\xe7\xbd\x91\xe5\x88\x9b\xe4\xb8\x9a\xe9\xa1\xb9\xe7\x9b\xae" />\r\n<meta name="description" content="36
# ...

# %%
soup = BeautifulSoup(content, 'html.parser')
print(soup.text)
# Out:
# 36氪_让一部分人先看到未来
#
# ...

# %%
print(soup.text)
# Out:
# 36氪_让一部分人先看到未来
#
# ...

# %%
#https://www.2cto.com/kf/201706/538498.html
doc = ['<html><head><title>Page title</title></head>',
       '<body><p id="firstpara" align="center">This is paragraph <b>one</b>.',
       '<p id="secondpara" align="blah">This is paragraph <b>two</b>.',
       '</html>']
soup = BeautifulSoup(''.join(doc),"lxml")

html_sample = soup.prettify()

# %%
print(html_sample)
# Out:
# <html>
#  <head>
#   <title>
#    Page title
#   </title>
#  </head>
#  <body>
#   <p align="center" id="firstpara">
#    This is paragraph
#    <b>
#     one
#    </b>
#    .
#   </p>
#   <p align="blah" id="secondpara">
#    This is paragraph
#    <b>
#     two
#    </b>
#    .
#   </p>
#  </body>
# </html>

# %%
soup = BeautifulSoup(html_sample, 'html.parser')
print(soup.text)
# Out:
#    Page title
#
#
#
#
#    This is paragraph
#
#     one
#
#    .
#
#
#    This is paragraph
#
#     two
#
#    .

# %%
html_sample = ' \
<html> \
 <body>  \
 <h1 id="title">Hello World</h1> \
 <a href="#" class="link"> This is link1</a> \
 <a href="# link2" class="link"> This is link2</a> \
 </body> \
 </html> ' 
print(html_sample)
# Out:
#  <html>  <body>   <h1 id="title">Hello World</h1>  <a href="#" class="link"> This is link1</a>  <a href="# link2" class="link"> This is link2</a>  </body>  </html>

# %%
soup = BeautifulSoup(html_sample, 'html.parser')
print(soup.text)
# Out:
#    Hello World  This is link1  This is link2

# %%
#深度学习课需要的样本集合
#百万级字符：清华大学提出中文自然文本数据集CTW
#https://ctwdataset.github.io/

# %%
#2,处理编码
#  字符集检测

# %%
url="http://www.jd.com"
  
def automatic_detect(url): 
  content=urllib.request.urlopen(url) .read() 
  result=chardet.detect(content) 
  
  encoding=result['encoding'] 
  print(encoding)
  return encoding 
  
urls=['http://www.baidu.com','http://www.163.com','http://dangdang.com'] 
for url in urls: 
  print(url)
  automatic_detect(url)
# Out:
# http://www.baidu.com
# utf-8
# http://www.163.com
# GB2312
# http://dangdang.com
# GB2312

# %%
#3,文档切分

# %%
#4,文档切分为句子

# %%
#5,文本分词
#  将字符串分解为词和标点符号；
#  经过分词，产生一个词汇和标点符号的链表

# %%
raw=html_sample
print(raw)
# Out:
#  <html>  <body>   <h1 id="title">Hello World</h1>  <a href="#" class="link"> This is link1</a>  <a href="# link2" class="link"> This is link2</a>  </body>  </html>

# %%
#nltk.download()
#tokenizers/punkt/PY3/english.pickle

# %%
#6,去标点

# %%
#7,去除非文字（英文|中文）字符的词

# %%
#8,去（英文|中文）停用词

# %%
#9,词型转换

# %%
#10,文本特征提取

# %%
#11,词频统计

# %%
#12,文本向量化

# %%
sent="hello,Python"

# %%
tokens=nltk.word_tokenize(sent)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-31-10efbd63a1d7> in <module>()
# ----> 1 tokens=nltk.word_tokenize(sent)
#
# /Users/bater.makhabel/anaconda3/lib/python3.6/site-packages/nltk/tokenize/__init__.py in word_tokenize(text, language)
#     107     :param language: the model name in the Punkt corpus
#     108     """
# --> 109     return [token for sent in sent_tokenize(text, language)
#     110             for token in _treebank_word_tokenize(sent)]
#     111
#
# /Users/bater.makhabel/anaconda3/lib/python3.6/site-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#      91     :param language: the model name in the Punkt corpus
#      92     """
# ---> 93     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
#      94     return tokenizer.tokenize(text)
#      95
#
# ...

# %%
import jieba
